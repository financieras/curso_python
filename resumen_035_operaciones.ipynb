# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/curso_python/blob/main/resumen/035_operaciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operaciones aritméticas
