# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/curso_python/blob/main/tasks/tasks_1_100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Task 1: Calcular el precio con IVA
# * **Contexto:** Estás programando una pequeña tienda online. Necesitas una función que calcule el precio final de un producto añadiendole el IVA (Impuesto sobre el Valor Añadido).
# * **Instrucciones:** Crea una función llamada `precio_total(precio_base, iva)` que reciba el precio base de un producto y devuelva el precio total añadiendo el IVA del producto, que habitualmente es el 21% pero puede ser otro.
# * **Ejemplos esperados:**
# 1. `precio_total(100, 21) ➞ 121.0`
# 2. `precio_total(200, 10) ➞ 220.0`
# 3. `precio_total(1000, 4) ➞ 1040.0`

# %%
# Solución 1
def precio_total(precio_base, iva):
    pass

# Solución 2
def precio_total(precio_base, iva):
    pass

# %%
print(precio_total(100, 21))
print(precio_total(200, 10))
print(precio_total(1000, 4))
