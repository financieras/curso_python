# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/curso_python/blob/main/mypy/funciones_matematicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sumar(n1,n2):
    print(f"El resultado de la suma es {n1+n2}")

def restar(n1,n2):
    print(f"El resultado de la resta es {n1-n2}")

def multiplicar(n1,n2):
    print(f"El resultado del producto es {n1*n2}")

def dividir(n1,n2):
    print(f"El resultado de la división es {n1/n2}")
